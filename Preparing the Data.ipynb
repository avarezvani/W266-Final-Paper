# %% [markdown]
# # Preparing the Data

# %%
## source: http://www.yelp.com/dataset challenge

## importing packages

import json
import os

import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### 1. Importing & Converting Data from JSON to CSV
#
# In the Yelp academic dataset that was provided, there are the following files:
#     - yelp_academic_dataset_user.json
#     - yelp_academic_dataset_tip.json
#     - yelp_academic_dataset_review.json
#     - yelp_academic_dataset_checkin.json
#     - yelp_academic_dataset_business.json
#
# For the purposes of this project, I will be using the following, given that I am interested in leveraging the reviews and tips that users have written for certain restaurant establishments:
#     - yelp_academic_dataset_tip.json
#     - yelp_academic_dataset_review.json
#     - yelp_academic_dataset_business.json
#
# In the following steps, I will be converting each of those json files to csv, for easier data analysis and manipulation.

# %%
# converting business.json into business_data.csv

business_data = {"business_id": [], "name": [], "postal_code": [], "stars": [], "review_count": [], "categories": []}

with open("/Users/avarezvani/Downloads/yelp-dataset/yelp_academic_dataset_business.json") as f:
    for line in tqdm(f):
        business = json.loads(line)
        business_data["business_id"].append(business["business_id"])
        business_data["name"].append(business["name"])
        business_data["postal_code"].append(business["postal_code"])
        business_data["stars"].append(business["stars"])
        business_data["review_count"].append(business["review_count"])
        business_data["categories"].append(business["categories"])

df = pd.DataFrame(business_data)

print(df.shape)
df.head()

df.to_csv("/Users/avarezvani/Downloads/yelp-dataset/business_data.csv", index=False)
# Out:
# 192609it [00:02, 70837.03it/s]
# (192609, 6)

# %%
# converting reviews.json into reviews_data.csv

reviews_data = {"review_id": [], "user_id": [], "business_id": [], "stars": [], "useful": [], "cool": [], "text": [], "date": []}

with open("/Users/avarezvani/Downloads/yelp-dataset/yelp_academic_dataset_review.json") as f:
    for line in tqdm(f):
        reviews = json.loads(line)
        reviews_data["review_id"].append(reviews["review_id"])
        reviews_data["user_id"].append(reviews["user_id"])
        reviews_data["business_id"].append(reviews["business_id"])
        reviews_data["stars"].append(reviews["stars"])
        reviews_data["useful"].append(reviews["useful"])
        reviews_data["cool"].append(reviews["cool"])
        reviews_data["text"].append(reviews["text"])
        reviews_data["date"].append(reviews["date"])

df = pd.DataFrame(reviews_data)

print(df.shape)
df.head()

df.to_csv("/Users/avarezvani/Downloads/yelp-dataset/reviews_data.csv", index=False)
# Out:
# 6685900it [00:57, 116817.88it/s]
# (6685900, 8)

# %%
# converting tips.json into tips_data.csv
# defintion of "tips", per Yelp's website
# "Tips are a way to pass along some key information about a business -- such as the best time to go or your favorite dish 
# -- without writing a full review about your experiences."

tips_data = {"user_id": [], "business_id": [], "text": [], "date": [], "compliment_count": []}

with open("/Users/avarezvani/Downloads/yelp-dataset/yelp_academic_dataset_tip.json") as f:
    for line in tqdm(f):
        tips = json.loads(line)
        tips_data["user_id"].append(tips["user_id"])
        tips_data["business_id"].append(tips["business_id"])
        tips_data["text"].append(tips["text"])
        tips_data["date"].append(tips["date"])
        tips_data["compliment_count"].append(tips["compliment_count"])

df = pd.DataFrame(tips_data)

print(df.shape)
df.head()

df.to_csv("/Users/avarezvani/Downloads/yelp-dataset/tips_data.csv", index=False)
# Out:
# 1223094it [00:05, 206552.45it/s]
# (1223094, 5)

# %% [markdown]
# ### 2. Importing New CSV Files & Cleaning to Identify Restaurant Information Only
#
# Starting with the business_data.csv, we are going to narrow down the categories to just restaurants. After that, we will then narrow down the tips_data.csv and the reviews_data.csv to match the business_id's that are leftover in the business_data set.

# %%
# business
df_business = pd.read_csv("/Users/avarezvani/Downloads/yelp-dataset/business_data.csv")
df_business.head()
# Out:
#               business_id                             name postal_code  stars  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club       85016    3.0
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant     L5R 3E7    2.5
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant       28210    4.0
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz       85338    5.0
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing       28217    4.0
#
#    review_count                                         categories
# 0             5                                  Golf, Active Life
# 1           128  Specialty Food, Restaurants, Dim Sum, Imported...
# 2           170                  Sushi Bars, Restaurants, Japanese
# 3             3                      Insurance, Financial Services
# 4             4  Plumbing, Shopping, Local Services, Home Servi...

# %%
# only keep category = "restaurants" in "business"
df_business_restaurants = df_business[df_business["categories"].str.contains("Restaurants", na = False)]

df_business_restaurants.count
print("There are 59,371 businesses that are restaurants")

# checking for any duplicates
df_business_restaurants.business_id.duplicated().sum()
print("There are no duplicates")
# Out:
# There are 59,371 businesses that are restaurants
# 0

# %%
# now let's filter out the reviews that do not match the remaining restaurants
df_reviews = pd.read_csv("/Users/avarezvani/Downloads/yelp-dataset/reviews_data.csv")

df_reviews_restaurants = pd.merge(df_business_restaurants, df_reviews, on = 'business_id')

df_reviews_restaurants.count
print("There are 4,201,684 reviews for these restaurants")

# %%
# finally, let's do the same thing we did for reviews, for the tips
df_tips = pd.read_csv("/Users/avarezvani/Downloads/yelp-dataset/tips_data.csv")

df_tips_restaurants = pd.merge(df_business_restaurants, df_tips, on = 'business_id')

df_tips_restaurants.count
print("There are 810,342 tips for these restaurants")
# Out:
# <bound method DataFrame.count of                    business_id                         name postal_code  \
# 0       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 1       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 2       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 3       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 4       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 5       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 6       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 7       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 8       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 9       QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 10      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 11      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 12      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 13      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 14      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 15      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 16      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 17      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 18      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 19      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 20      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 21      QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant     L5R 3E7
# 22      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 23      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 24      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 25      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 26      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 27      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 28      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# 29      gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant       28210
# ...                        ...                          ...         ...
# 810312  3HAPJH0Qoi8Ix6M9rUMfjg                  Indian Hero     L6P 3A3
# 810313  3HAPJH0Qoi8Ix6M9rUMfjg                  Indian Hero     L6P 3A3
# 810314  3HAPJH0Qoi8Ix6M9rUMfjg                  Indian Hero     L6P 3A3
# 810315  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810316  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810317  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810318  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810319  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810320  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810321  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810322  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810323  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810324  oS0CnUbyv0GUoD3L8_3UPQ                 Thai Fantasy     M4Y 1Z3
# 810325  ghovD5ZTGDQ5Q2U4ERddWw                    Five Guys       44333
# 810326  ghovD5ZTGDQ5Q2U4ERddWw                    Five Guys       44333
# 810327  ghovD5ZTGDQ5Q2U4ERddWw                    Five Guys       44333
# 810328  ghovD5ZTGDQ5Q2U4ERddWw                    Five Guys       44333
# 810329  ghovD5ZTGDQ5Q2U4ERddWw                    Five Guys       44333
# 810330  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810331  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810332  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810333  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810334  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810335  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810336  KnafX7T6qSAmSrLhd709vA              Pho Maisonneuve     H2L 1Z1
# 810337  p1eUTUB_5hf1enoKYBV3DA      Ken Stewart's Tre Belle       44210
# 810338  p1eUTUB_5hf1enoKYBV3DA      Ken Stewart's Tre Belle       44210
# 810339  p1eUTUB_5hf1enoKYBV3DA      Ken Stewart's Tre Belle       44210
# 810340  p1eUTUB_5hf1enoKYBV3DA      Ken Stewart's Tre Belle       44210
# 810341  p1eUTUB_5hf1enoKYBV3DA      Ken Stewart's Tre Belle       44210
#
#         stars  review_count  \
# 0         2.5           128
# 1         2.5           128
# 2         2.5           128
# 3         2.5           128
# 4         2.5           128
# 5         2.5           128
# 6         2.5           128
# 7         2.5           128
# 8         2.5           128
# 9         2.5           128
# 10        2.5           128
# 11        2.5           128
# 12        2.5           128
# 13        2.5           128
# 14        2.5           128
# 15        2.5           128
# 16        2.5           128
# 17        2.5           128
# 18        2.5           128
# 19        2.5           128
# 20        2.5           128
# 21        2.5           128
# 22        4.0           170
# 23        4.0           170
# 24        4.0           170
# 25        4.0           170
# 26        4.0           170
# 27        4.0           170
# 28        4.0           170
# 29        4.0           170
# ...       ...           ...
# 810312    3.0            39
# 810313    3.0            39
# 810314    3.0            39
# 810315    4.0           113
# 810316    4.0           113
# 810317    4.0           113
# 810318    4.0           113
# 810319    4.0           113
# 810320    4.0           113
# 810321    4.0           113
# 810322    4.0           113
# 810323    4.0           113
# 810324    4.0           113
# 810325    4.0            22
# 810326    4.0            22
# 810327    4.0            22
# 810328    4.0            22
# 810329    4.0            22
# 810330    4.0            25
# 810331    4.0            25
# 810332    4.0            25
# 810333    4.0            25
# 810334    4.0            25
# 810335    4.0            25
# 810336    4.0            25
# 810337    3.5            39
# 810338    3.5            39
# 810339    3.5            39
# 810340    3.5            39
# 810341    3.5            39
#
#                                                categories  \
# 0       Specialty Food, Restaurants, Dim Sum, Imported...
# 1       Specialty Food, Restaurants, Dim Sum, Imported...
# 2       Specialty Food, Restaurants, Dim Sum, Imported...
# 3       Specialty Food, Restaurants, Dim Sum, Imported...
# 4       Specialty Food, Restaurants, Dim Sum, Imported...
# 5       Specialty Food, Restaurants, Dim Sum, Imported...
# 6       Specialty Food, Restaurants, Dim Sum, Imported...
# 7       Specialty Food, Restaurants, Dim Sum, Imported...
# 8       Specialty Food, Restaurants, Dim Sum, Imported...
# 9       Specialty Food, Restaurants, Dim Sum, Imported...
# 10      Specialty Food, Restaurants, Dim Sum, Imported...
# 11      Specialty Food, Restaurants, Dim Sum, Imported...
# 12      Specialty Food, Restaurants, Dim Sum, Imported...
# 13      Specialty Food, Restaurants, Dim Sum, Imported...
# 14      Specialty Food, Restaurants, Dim Sum, Imported...
# 15      Specialty Food, Restaurants, Dim Sum, Imported...
# 16      Specialty Food, Restaurants, Dim Sum, Imported...
# 17      Specialty Food, Restaurants, Dim Sum, Imported...
# 18      Specialty Food, Restaurants, Dim Sum, Imported...
# 19      Specialty Food, Restaurants, Dim Sum, Imported...
# 20      Specialty Food, Restaurants, Dim Sum, Imported...
# 21      Specialty Food, Restaurants, Dim Sum, Imported...
# 22                      Sushi Bars, Restaurants, Japanese
# 23                      Sushi Bars, Restaurants, Japanese
# 24                      Sushi Bars, Restaurants, Japanese
# 25                      Sushi Bars, Restaurants, Japanese
# 26                      Sushi Bars, Restaurants, Japanese
# 27                      Sushi Bars, Restaurants, Japanese
# 28                      Sushi Bars, Restaurants, Japanese
# 29                      Sushi Bars, Restaurants, Japanese
# ...                                                   ...
# 810312                                Restaurants, Indian
# 810313                                Restaurants, Indian
# 810314                                Restaurants, Indian
# 810315                                  Restaurants, Thai
# 810316                                  Restaurants, Thai
# 810317                                  Restaurants, Thai
# 810318                                  Restaurants, Thai
# 810319                                  Restaurants, Thai
# 810320                                  Restaurants, Thai
# 810321                                  Restaurants, Thai
# 810322                                  Restaurants, Thai
# 810323                                  Restaurants, Thai
# 810324                                  Restaurants, Thai
# 810325    Burgers, Restaurants, Fast Food, American (New)
# 810326    Burgers, Restaurants, Fast Food, American (New)
# 810327    Burgers, Restaurants, Fast Food, American (New)
# 810328    Burgers, Restaurants, Fast Food, American (New)
# 810329    Burgers, Restaurants, Fast Food, American (New)
# 810330                      Vietnamese, Soup, Restaurants
# 810331                      Vietnamese, Soup, Restaurants
# 810332                      Vietnamese, Soup, Restaurants
# 810333                      Vietnamese, Soup, Restaurants
# 810334                      Vietnamese, Soup, Restaurants
# 810335                      Vietnamese, Soup, Restaurants
# 810336                      Vietnamese, Soup, Restaurants
# 810337                               Restaurants, Italian
# 810338                               Restaurants, Italian
# 810339                               Restaurants, Italian
# 810340                               Restaurants, Italian
# 810341                               Restaurants, Italian
#
#                        user_id  \
# 0       fENhF1F6I9c2ssnkfprYzw
# 1       RscJR5zqb3WL4eQezBX5rA
# 2       nyl_1VcRIAyI55bb_scpdw
# 3       fENhF1F6I9c2ssnkfprYzw
# 4       ci8R1Bg83hNwXPyHAEzAFA
# 5       TjsBbWAfwxWEXPxaLNv5SQ
# 6       ismHJRDRvxw8MYKng9R_yg
# 7       CjbfWpCRLbA-L_eS_ztd6Q
# 8       oIHhfloe5VQamDFDB2dr1Q
# 9       ZVLMi7_FcWu-04_EbQF4HQ
# 10      iBBLkWtXWzOUUjhT7IqUBA
# 11      ismHJRDRvxw8MYKng9R_yg
# 12      fENhF1F6I9c2ssnkfprYzw
# 13      Weyd9u16itD_Li91RYLPQA
# 14      74goFJSWzAwmk69XfPqEag
# 15      fENhF1F6I9c2ssnkfprYzw
# 16      cxa_z7wFYAyveCIB0t8NLw
# 17      cmEvYiO6LC8-4Vcc79QZWQ
# 18      q95xzZ_DJNfINOIyZVAWvQ
# 19      mWCAV-hs6hJrprIj0PXUQQ
# 20      0Lg0CafCSPvr4oHG1zMJ4A
# 21      9-4-FQ4KuqxL193IXn_gBw
# 22      JysF40STBTmx7h-sU1FHgg
# 23      FyikYazQbNoOumDooOQyyA
# 24      FyikYazQbNoOumDooOQyyA
# 25      7M-rWYRGPfCDnb7tjl7QGQ
# 26      MZFUSBTj7RDpf19v5qP9HA
# 27      tJ-CO-eQQGOSvoXF6we12w
# 28      4m_44zfmfIEnvWxj-qf3XA
# 29      JysF40STBTmx7h-sU1FHgg
# ...                        ...
# 810312  bJvLnfddjxVkBqK1Zs7duQ
# 810313  bF48iBNL4Db1mByR8aqUNw
# 810314  sWfMFF6Q5-pQfli98gzS4Q
# 810315  0IwZb1ePNpSVYcCdMtGoQw
# 810316  n2mAOAYORrenCeFlgRphjA
# 810317  QPJJohtGqkMkaN0Gt3TRIg
# 810318  0BaJ43WuBnP-G6fmstEmNQ
# 810319  0BaJ43WuBnP-G6fmstEmNQ
# 810320  0BaJ43WuBnP-G6fmstEmNQ
# 810321  4dydCLQ1lyEFbBuDLkpjSw
# 810322  Vex4RF6ZCVdItCIw3Iugtw
# 810323  wffiE52sIzlX5B6ZZ47qVQ
